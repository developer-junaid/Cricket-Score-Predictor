# %%
import pandas as pd
import numpy as np
import pickle

# %%
data = pd.read_csv('t20_dataset.csv', index_col=0)

# %%
data = pd.get
# Out:
#        batting_team  bowling_team        city  current_score  balls_left  \
# 31184   West Indies    Bangladesh      Mirpur             79          45
# 28866      Pakistan  South Africa   Abu Dhabi             96          19
# 30208  South Africa   New Zealand    Auckland            125          40
# 8641       Pakistan     Australia       Dubai             72          62
# 48889   Afghanistan   West Indies      Nagpur             53          54
# ...             ...           ...         ...            ...         ...
# 13032    Bangladesh      Pakistan      Lahore            115          17
# 19746       England   West Indies    Trinidad            112          24
# 19473     Australia  South Africa   Melbourne            116          51
# 1151    West Indies         India  Lauderhill             90          82
# 34998         India     Sri Lanka   Pallekele            142          12
#
#        wickets_left        crr  last_five  runs_x
# 31184             8   6.320000       25.0     132
# 28866             2   5.702970       13.0     119
# 30208             6   9.375000       59.0     165
# 8641             10   7.448276       31.0     150
# 48889             6   4.818182       20.0     123
# ...             ...        ...        ...     ...
# 13032             6   6.699029       39.0     136
# 19746             4   7.000000       29.0     121
# 19473             8  10.086957       42.0     182
# 1151             10  14.210526       72.0     245
# 34998             7   7.888889       36.0     155
#
# [38477 rows x 9 columns]

# %%
# spilting the data into training and testing 

X = data.drop(columns=['runs_x'])
y = data['runs_x']
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=1)

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor

# %%
trf = ColumnTransformer([
    ('trf',OneHotEncoder(sparse=False,drop='first'),['batting_team','bowling_team','city'])
]
,remainder='passthrough')

# %%
pipe = Pipeline(steps=[
    ('step1',trf),
    ('step2',StandardScaler()),
    ('step3',RandomForestRegressor(n_estimators = 20, random_state = 1))
    ])

# %%
pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('step1',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('trf',
#                                                   OneHotEncoder(drop='first',
#                                                                 sparse=False),
#                                                   ['batting_team',
#                                                    'bowling_team', 'city'])])),
#                 ('step2', StandardScaler()),
#                 ('step3',
#                  RandomForestRegressor(n_estimators=20, random_state=1))])

# %%
from sklearn.metrics import r2_score,mean_absolute_error
from sklearn.metrics import mean_squared_error 

y_pred = pipe.predict(X_test)
print(r2_score(y_test,y_pred))
print(mean_absolute_error(y_test,y_pred))
print(mean_squared_error(y_test, y_pred))
# Out:
# 0.9760230820313067
# 2.2391873484060985
# 23.79317089225644

# %%
import plotly.express as px

fig = px.scatter(x=y_test, y=y_pred, color=y_test, title='Random Forest', width=700, height=500, )
fig.update_traces(marker_size=10)
fig.update_xaxes(title_text='REAL VALUE')
fig.update_yaxes(title_text='PREDICT VALUE')
fig.show()
# Out:
# <div>                            <div id="b6137e9f-b983-4e50-beec-7e8b83902ee2" class="plotly-graph-div" style="height:500px; width:700px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b6137e9f-b983-4e50-beec-7e8b83902ee2")) {                    Plotly.newPlot(                        "b6137e9f-b983-4e50-beec-7e8b83902ee2",                        [{"hovertemplate":"x=%{x}<br>y=%{y}<br>color=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[147,139,157,115,231,119,156,126,152,129,171,240,124,157,155,160,122,105,191,151,165,196,159,159,135,191,141,138,162,168,115,150,183,120,126,191,171,147,196,123,169,164,155,164,176,159,155,108,169,198,138,188,153,111,155,263,118,146,137,101,119,245,154,147,191,105,196,182,142,153,166,196,132,152,196,143,127,179,159,111,153,142,150,141,160,243,153,133,146,205,150,144,168,191,191,240,129,150,113,183,154,125,177,243,188,208,89,145,144,191,162,141,191,197,158,118,192,159,146,215,139,78,170,171,137,159,202,113,171,142,194,158,149,172,142,179,113,113,159,171,120,110,140,122,140,195,203,241,140,147,137,185,161,179,197,132,191,197,189,120,180,166,166,136,141,137,121,143,168,248,128,135,129,157,165,128,146,233,196,205,139,101,162,178,141,128,194,154,135,206,197,142,143,166,174,160,153,174,118,149,169,149,153,153,164,160,127,164,159,98,198,142,204,194,143,165,191,165,163,115,105,221,198,196,155,147,172,147,147,189,134,129,183,128,174,152,156,159,194,181,180,157,219,160,180,195,101,135,165,115,152,120,177,163,159,124,191,191,119,152,120,141,243,164,180,214,166,96,186,